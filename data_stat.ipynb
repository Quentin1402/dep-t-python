# %%
import numpy as np
import pandas as pd
import seaborn as sb

house = pd.read_csv('C:/Users/asus tuf/Downloads/house_pricing.csv');
house.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
sb.set(style='whitegrid')
tmp = house[house['SalePrice'] < 500000]
tmp2 = tmp[tmp["LotArea"] < 20000]
sb.set(rc={'figure.figsize':(11.7,8.27)})
sb.scatterplot(x="SalePrice", y="LotArea", data = tmp2)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
house = pd.read_csv('C:/Users/asus tuf/Downloads/house_pricing.csv');
tmp = house[house['LotFrontage'] < 200]
tmp2 = tmp[tmp['LotArea'] < 100000]
sb.scatterplot(x="LotFrontage", y="LotArea", data = tmp2)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='LotArea'>

# %%
sale = pd.read_csv('C:/Users/asus tuf/Downloads/sales_predictions.csv');
sale = sale.sample(n=50)
sb.relplot(x=pd.to_datetime(sale["date"]), y="item_price", data=sale, height=10)

# %%
ibm = pd.read_csv('C:/Users/asus tuf/Downloads/ibm_hr_attrition.csv');
sb.catplot(x="Attrition", y="JobSatisfaction", data=ibm, height = 10)

# %%
sb.boxplot(x="JobSatisfaction", y="Attrition", data=ibm)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='Attrition'>

# %%
ibm["JobSatisfaction"].describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
sb.boxplot(x="TotalWorkingYears", y="Attrition", data=ibm)
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='Attrition'>

# %%
tmp = ibm[ibm["TotalWorkingYears"] < 20]
sb.boxplot(x="Attrition", y="TotalWorkingYears", data=tmp)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='TotalWorkingYears'>

# %%
ibm["Attrition"].replace({"Yes": 1, "No": 0}, inplace=True)
sb.boxplot(x="Attrition", y="TotalWorkingYears", data=ibm)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='TotalWorkingYears'>

# %%
sb.catplot(x="EducationField", y="Attrition", data = ibm, kind="bar", height=10)

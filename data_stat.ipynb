# %%
import numpy as np
import pandas as pd
import seaborn as sb

house = pd.read_csv('C:/Users/asus tuf/Downloads/house_pricing.csv');
house.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
sb.set(style='whitegrid')
Sale = house[house["SalePrice"] < 500000]
Lot = house[house["LotArea"] < 20000]
sb.scatterplot(x="SalePrice", y="LotArea", data = house)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

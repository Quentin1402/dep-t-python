# %%
import numpy as np
import pandas as pd
import seaborn as sb

house = pd.read_csv('C:/Users/asus tuf/Downloads/house_pricing.csv');
house.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
sb.set(style='whitegrid')
tmp = house[house['SalePrice'] < 500000]
tmp2 = tmp[tmp["LotArea"] < 20000]
sb.set(rc={'figure.figsize':(11.7,8.27)})
sb.scatterplot(x="SalePrice", y="LotArea", data = tmp2)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='LotArea'>

# %%
house = pd.read_csv('C:/Users/asus tuf/Downloads/house_pricing.csv');
tmp = house[house['LotFrontage'] < 200]
tmp2 = tmp[tmp['LotArea'] < 100000]
sb.scatterplot(x="LotFrontage", y="LotArea", data = tmp2)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='LotArea'>

# %%
sale = pd.read_csv('C:/Users/asus tuf/Downloads/sales_predictions.csv');
sale = sale.sample(n=50)
sb.relplot(x=pd.to_datetime(sale["date"]), y="item_price", data=sale, height=10)

# %%
ibm = pd.read_csv('C:/Users/asus tuf/Downloads/ibm_hr_attrition.csv');
ibm.dtypes
sb.catplot(x="JobSatisfaction", y="YearsAtCompany", data=ibm)

# %%
sb.boxplot(x="JobSatisfaction", y="YearsAtCompany", data=ibm)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='YearsAtCompany'>

# %%
ibm.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...
